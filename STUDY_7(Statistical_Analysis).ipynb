# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavanaTK/CASE-STUDIES/blob/main/STUDY_7(Statistical_Analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA PM10

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Admin\Desktop\BHAVANA\PM10.xlsx")
df
# Out:
#      Time   Prelock  stdev     Lock  stdev.1  stdev.2  tripplelock
# 0    0.25  118.5000   12.0  93.0435      8.5    60.45          8.5
# 1    0.50  120.4000   12.0  92.1739      8.5    60.65          8.5
# 2    0.75  116.5000   13.0  84.3478      6.4    56.95          6.4
# 3    1.00  114.2000   14.0  80.0000      5.5    56.49          5.5
# 4    1.25  110.2000   13.0  78.2609      6.5    58.60          6.5
# ..    ...       ...    ...      ...      ...      ...          ...
# 91  23.00  113.0435   10.0  79.5000      6.0    69.98          6.0
# 92  23.25  117.5000   11.0  83.5000      7.0    62.64          7.0
# 93  23.50  116.5000   13.0  86.5000      5.0    61.62          5.0
# 94  23.75  117.5000   10.0  84.5000      6.0    64.36          6.0
# 95  24.00  120.4000   12.0  80.5000      8.0    64.70          8.0
#
# [96 rows x 7 columns]

# %%
df.head()
# Out:
#    Time  Prelock  stdev     Lock  stdev.1  stdev.2  tripplelock
# 0  0.25    118.5   12.0  93.0435      8.5    60.45          8.5
# 1  0.50    120.4   12.0  92.1739      8.5    60.65          8.5
# 2  0.75    116.5   13.0  84.3478      6.4    56.95          6.4
# 3  1.00    114.2   14.0  80.0000      5.5    56.49          5.5
# 4  1.25    110.2   13.0  78.2609      6.5    58.60          6.5

# %%
df.tail()
# Out:
#      Time   Prelock  stdev  Lock  stdev.1  stdev.2  tripplelock
# 91  23.00  113.0435   10.0  79.5      6.0    69.98          6.0
# 92  23.25  117.5000   11.0  83.5      7.0    62.64          7.0
# 93  23.50  116.5000   13.0  86.5      5.0    61.62          5.0
# 94  23.75  117.5000   10.0  84.5      6.0    64.36          6.0
# 95  24.00  120.4000   12.0  80.5      8.0    64.70          8.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time         96 non-null     float64
#  1   Prelock      96 non-null     float64
#  2   stdev        96 non-null     float64
#  3   Lock         96 non-null     float64
#  4   stdev.1      96 non-null     float64
#  5   stdev.2      96 non-null     float64
#  6   tripplelock  96 non-null     float64
# dtypes: float64(7)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#             Time     Prelock      stdev       Lock    stdev.1    stdev.2  \
# count  96.000000   96.000000  96.000000  96.000000  96.000000  96.000000
# mean   12.125000  106.329078  14.425000  69.157834   9.175000  51.545417
# std     6.964194   12.046039   3.040949   7.821546   2.880753   6.701706
# min     0.250000   80.680000   9.000000  55.652200   5.000000  40.200000
# 25%     6.187500   97.472825  12.000000  63.500000   7.375000  46.650000
# 50%    12.125000  106.100000  14.000000  68.400000   8.550000  50.200000
# 75%    18.062500  116.500000  16.850000  74.301100  10.000000  55.465000
# max    24.000000  127.800000  22.000000  93.043500  15.000000  70.200000
#
#        tripplelock
# count    96.000000
# mean      7.788542
# std       1.336363
# min       5.000000
# 25%       7.000000
# 50%       8.000000
# 75%       8.800000
# max      10.000000

# %%
df.shape
# Out:
# (96, 7)

# %%
df.corr()
# Out:
#                  Time   Prelock     stdev      Lock   stdev.1   stdev.2  \
# Time         1.000000  0.006297 -0.341918 -0.185122 -0.392006  0.392188
# Prelock      0.006297  1.000000  0.149341  0.459632  0.276702  0.294610
# stdev       -0.341918  0.149341  1.000000 -0.345540  0.797336 -0.679149
# Lock        -0.185122  0.459632 -0.345540  1.000000 -0.319629  0.563652
# stdev.1     -0.392006  0.276702  0.797336 -0.319629  1.000000 -0.596743
# stdev.2      0.392188  0.294610 -0.679149  0.563652 -0.596743  1.000000
# tripplelock -0.417795 -0.265257  0.270235 -0.199275  0.477880 -0.404556
#
#              tripplelock
# Time           -0.417795
# Prelock        -0.265257
# stdev           0.270235
# Lock           -0.199275
# stdev.1         0.477880
# stdev.2        -0.404556
# tripplelock     1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.show()

# %%
df.hist(figsize=(15,15))
plt.show()

# %%
x=df[["Time","Prelock","stdev","Lock","stdev.1","stdev.2"]]
y=df["tripplelock"]

# %%
fig,axs = plt.subplots(3,figsize = (5,5))
plt1 = sns.boxplot(df["Time"],ax=axs[0])
plt2 = sns.boxplot(df["Admin"],ax = axs[1])
plt3 = sns.boxplot(df["Marketing Spend"],ax = axs[2])
plt.tight_layout()
